# %%
import sys
import os

project_root = os.path.abspath(os.path.join("..", ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

print(project_root)
# Out:
# c:\Programming\VSCode Project\Lion\workspace\멋사 DataThon_Project_env

# %%
from src.collector_naver_cafe import (
    scrape_naver_cafe_posts,
)

# %%
test_df = scrape_naver_cafe_posts(
    keyword="렉스트림",
    start_date="2026-01-01",
    end_date="2026-03-30",
    headless=False
)

display(test_df)
# Out:
#    query_keyword                                              title  \
# 0           렉스트림                        <필독> 월요일 오후 6시 30분 수업 변경 공지
# 1           렉스트림                   [운영] 내일(수) 오후 수업은 렉스트림 으로 진행 합니다
# 2           렉스트림                        260204 Rextreme / 렉스트림 (수정)
# 3           렉스트림                                    260126 CrossFit
# 4           렉스트림                                        조금전 일산에서는 !
# 5           렉스트림                                       1/23 홀딩신청합니다
# 6           렉스트림                                   렉스트림 대회 참가 혜택 안내
# 7           렉스트림                                      이번주 토요일 수업 공지
# 8           렉스트림                                  1/24 REXTREME 대회!
# 9           렉스트림          피지컬100, 아시아피지컬100 하이록스운동을 할 수 있는 위무브트레이닝!
# 10          렉스트림                                   [사진] 렉스트림 사진!(2)
# 11          렉스트림                                   [사진] 렉스트림 사진!(1)
# 12          렉스트림                                            렉스트림 사진
# 13          렉스트림                                렉스트림 대체 참가자 (3인 팀전)
# 14          렉스트림                                     1/10 드랍인 신청합니다
# 15          렉스트림  [이벤트]✔️Rextreme ( 렉스트림 ) 하이브리드 피트니스 레이스에 참여하세요...
#
#                                             full_text  \
# 0   문서 저장하기 Keep에 저장 Keep 바로가기 윈썸크로스핏 2026.02.09. ...
# 1   문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 강남개포점 202...
# 2   문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 강남개포점 202...
# 3   문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 수원 장안점 20...
# 4   문서 저장하기 Keep에 저장 Keep 바로가기 인천 크로스핏032 [CrossFi...
# 5   문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 수원 장안점 20...
# 6   문서 저장하기 Keep에 저장 Keep 바로가기 하얀짐 [ 여성 기능성 그룹운동 센...
# 7   문서 저장하기 Keep에 저장 Keep 바로가기 크로스핏 로얄 2026.01.21....
# 8   문서 저장하기 Keep에 저장 Keep 바로가기 요야와 오징어 집 2026.01.1...
# 9   문서 저장하기 Keep에 저장 Keep 바로가기 나눔카페 [구]광명맘&대디 -광명시...
# 10  문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 동탄점 2026....
# 11  문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 동탄점 2026....
# 12  문서 저장하기 Keep에 저장 Keep 바로가기 하이엔드크로스핏 2026.01.09...
# 13  문서 저장하기 Keep에 저장 Keep 바로가기 크로스핏제우스 2026.01.07....
# 14  문서 저장하기 Keep에 저장 Keep 바로가기 어라운드 크로스핏 동탄점 2026....
# 15  문서 저장하기 Keep에 저장 Keep 바로가기 어라운드크로스핏 평택점 2026.0...
#
#                                                   url    date_text  \
# 0   https://cafe.naver.com/winsomecf/1288?art=ZXh0...  2026.02.09.
# 1   https://cafe.naver.com/geapo/2490?art=ZXh0ZXJu...  2026.02.03.
# 2   https://cafe.naver.com/geapo/2489?art=ZXh0ZXJu...  2026.02.03.
# 3   https://cafe.naver.com/aroundjangan/5712?art=Z...  2026.01.25.
# 4   https://cafe.naver.com/crossfit032/15052?art=Z...  2026.01.24.
# 5   https://cafe.naver.com/aroundjangan/5705?art=Z...  2026.01.23.
# 6   https://cafe.naver.com/hayangymseoul/112?art=Z...  2026.01.21.
# 7   https://cafe.naver.com/crossfitroyal/4224?art=...  2026.01.21.
# 8   https://cafe.naver.com/yoya/438?art=ZXh0ZXJuYW...  2026.01.19.
# 9   https://cafe.naver.com/ilovegm1/2608259?art=ZX...  2026.01.14.
# 10  https://cafe.naver.com/impcrossfit/55233?art=Z...  2026.01.11.
# 11  https://cafe.naver.com/impcrossfit/55232?art=Z...  2026.01.11.
# 12  https://cafe.naver.com/highendcrossfit/606?art...  2026.01.09.
# 13  https://cafe.naver.com/crossfitzeus/2181?art=Z...  2026.01.07.
# 14  https://cafe.naver.com/impcrossfit/55171?art=Z...  2026.01.07.
# 15  https://cafe.naver.com/around6/12020?art=ZXh0Z...  2026.01.06.
#
#    parsed_date  has_kor  has_eng  has_any
# 0   2026-02-09     True     True     True
# 1   2026-02-03     True     True     True
# 2   2026-02-03     True     True     True
# 3   2026-01-25     True    False     True
# 4   2026-01-24     True    False     True
# 5   2026-01-23     True    False     True
# 6   2026-01-21     True    False     True
# 7   2026-01-21     True    False     True
# 8   2026-01-19     True     True     True
# 9   2026-01-14     True     True     True
# 10  2026-01-11     True    False     True
# 11  2026-01-11     True    False     True
# 12  2026-01-09     True    False     True
# 13  2026-01-07     True    False     True
# 14  2026-01-07     True    False     True
# 15  2026-01-06     True     True     True
